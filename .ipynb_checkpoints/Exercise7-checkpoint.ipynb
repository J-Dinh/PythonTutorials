# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("datasets/007ExerciseFile.csv")

# %%
display(data)
# Out:
#        Strain  Mutation_rate
# 0    st_alpha      10.612005
# 1    st_alpha      12.586371
# 2    st_alpha       8.997583
# 3    st_alpha      11.681775
# 4    st_alpha      14.408237
# ..        ...            ...
# 163  st_delta       2.716249
# 164  st_delta       2.467378
# 165  st_delta       2.119801
# 166  st_delta       1.316537
# 167  st_delta       2.060472
#
# [168 rows x 2 columns]

# %%
sns.displot(data, x="Mutation_rate", hue="Strain", kind="hist", alpha=.4)

# %%
sns.displot(data, x="Mutation_rate", hue="Strain", kind="kde")

# %%
sns.violinplot(data=data, x="Strain", y="Mutation_rate")
# Out:
# <AxesSubplot:xlabel='Strain', ylabel='Mutation_rate'>

# %%
sns.boxplot(data=data, x="Strain", y="Mutation_rate")
# Out:
# <AxesSubplot:xlabel='Strain', ylabel='Mutation_rate'>

# %%
sns.boxplot(data=data, x="Strain", y="Mutation_rate")
sns.stripplot(data=data, x="Strain", y="Mutation_rate", alpha = .3)
# Out:
# <AxesSubplot:xlabel='Strain', ylabel='Mutation_rate'>

# %% [markdown]
# Plot to show Anthony Fauci

# %%
sns.set_style("darkgrid")
sns.displot(data, x="Mutation_rate", hue="Strain", kind="kde", fill=True, alpha=.4, legend=False)
plt.xlabel("Mutation Rate")
plt.title("Mutation Rates for 4 Virus Strains")
plt.xticks(np.arange(0, 20, 2))
plt.legend(["Delta", "Gamma", "Beta", "Alpha"], title="Strains")

# %% [markdown]
# The KDE plot shows that each strain has a different mutation rate. The Alpha strain has a large range of mutation rates with the average being around 10 mutations per generation x 10e-5. The Beta strain has a slightly smaller range but more desnity for around 5 mutations. The Delta strain has little range but high density for 2 mutations. The Gamma range has the smallest range and highest density for 1 mutation.
